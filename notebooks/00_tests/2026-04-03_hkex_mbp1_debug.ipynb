# %% [markdown]
# # HKEX MBP-1 reconstruction DEBUG

# %%
import DestinyResearch as dr

# %%
tbl = dr.get_mbp1_front("HSI", "2026-02-03")
# Out:
# [dr] Front month for HSI on 2026-02-03: HSIG26

# %%
tbl.shape
# Out:
# (10071753, 13)

# %%
df = tbl.to_pandas()

# %%
df.columns
# Out:
# Index(['ts_event', 'ts_recv', 'action', 'side', 'price', 'flags', 'sequence',
#        'bid_px_00', 'ask_px_00', 'bid_sz_00', 'ask_sz_00', 'bid_ct_00',
#        'ask_ct_00'],
#       dtype='str')

# %%
df[df.bid_px_00 > df.ask_px_00]
# Out:
#                      ts_event              ts_recv  action side    price  \
# 953       1770081301462000000  1770081301462000000     ADD  ASK  27046.0
# 954       1770081301463000000  1770081301463000000     ADD  ASK  27068.0
# 955       1770081301460000000  1770081301463000000   TRADE  BID  27046.0
# 956       1770081301460000000  1770081301463000000   TRADE  BID  27046.0
# 957       1770081301463000000  1770081301463000000  CANCEL  ASK      0.0
# ...                       ...                  ...     ...  ...      ...
# 10071748  1770145200013000000  1770145200013000000     ADD  ASK  26684.0
# 10071749  1770145200040000000  1770145200040000000  CANCEL  ASK      0.0
# 10071750  1770145200040000000  1770145200040000000  CANCEL  BID      0.0
# 10071751  1770145200040000000  1770145200040000000  CANCEL  ASK      0.0
# 10071752  1770145200040000000  1770145200040000000  CANCEL  BID      0.0
#
#           flags   sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  \
# ...

# %%
df.loc[0:10]
# Out:
#                ts_event              ts_recv action side    price  flags  \
# 0   1770066427752000000  1770066427752000000    ADD  BID  26915.0    132
# 1   1770066427752000000  1770066427752000000    ADD  BID  26912.0    132
# 2   1770066427752000000  1770066427752000000    ADD  BID  26900.0    132
# 3   1770066427752000000  1770066427752000000    ADD  BID  26900.0    132
# 4   1770066427752000000  1770066427752000000    ADD  BID  26860.0    132
# 5   1770066427752000000  1770066427752000000    ADD  BID  26855.0    132
# 6   1770066427752000000  1770066427752000000    ADD  BID  26850.0    132
# 7   1770066427752000000  1770066427752000000    ADD  BID  26844.0    132
# 8   1770066427752000000  1770066427752000000    ADD  BID  26828.0    132
# 9   1770066427752000000  1770066427752000000    ADD  BID  26811.0    132
# 10  1770066427752000000  1770066427752000000    ADD  BID  26806.0    132
#
#     sequence  bid_px_00  ask_px_00  bid_sz_00  ask_sz_00  bid_ct_00  ask_ct_00
# ...
