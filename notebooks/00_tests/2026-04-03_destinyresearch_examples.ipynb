# %%
import DestinyResearch as dr

# %% [markdown]
# # DestinyResearch data access

# %% [markdown]
# **Data overview**

# %%
dr.overview()
# Out:
# ...
#   DestinyResearch — Data Overview
# ...
#   ES      —   27 days  [2025-10-01 → 2025-10-31]
#   FDAX    —   21 days  [2025-05-02 → 2025-05-30]
#   FESX    —   21 days  [2025-05-02 → 2025-05-30]
#   FSMI    —   21 days  [2025-05-02 → 2025-05-30]
#   HHI     —   20 days  [2026-02-02 → 2026-02-27]
#   HSI     —   20 days  [2026-02-02 → 2026-02-27]
#   MCH     —   20 days  [2026-02-02 → 2026-02-27]
#   MHI     —   20 days  [2026-02-02 → 2026-02-27]
#   NIY     —  363 days  [2025-01-01 → 2026-02-27]
#   NKD     —  363 days  [2025-01-01 → 2026-02-27]
# ...
#
# Quick start:
#   tbl = dr.get_mbo_front('ES', '2025-10-01')
#   tbl = dr.get_mbp1('ESZ25', '2025-10-01', columns=['ts_recv','bid_px_00','ask_px_00'])
#   df  = dr.to_df(tbl)
#   dr.show_info('HSI')

# %% [markdown]
# **Available products**

# %%
dr.get_available_products()
# Out:
# ['ES', 'NIY', 'NKD', 'FDAX', 'FESX', 'FSMI', 'HSI', 'MHI', 'HHI', 'MCH']

# %% [markdown]
# **Product info**

# %%
dr.show_info("HSI")
# Out:
# ────────────────────────────────────────────────────────────
#   HSI  —  Hang Seng Index Future (HKEX)
# ────────────────────────────────────────────────────────────
#   Exchange      : HKEX  |  Provider: HKEX
#   Currency      : HKD  |  Point value: 50.0 HKD/pt
#   Tick size     : 1.0000 pts
#   Price floor   : 5000 pts
#   Timezone      : Asia/Hong_Kong
#   Session UTC   : 01:15:00 → 08:30:00
#   RTH (UTC)     : 01:15:00 → 08:30:00
#   Lunch break   : 04:00:00 → 05:00:00 UTC
#   Contracts     : ['HSIG26', 'HSIH26', 'HSIH27', 'HSIJ26', 'HSIK26', 'HSIM26', 'HSIM27', 'HSIM28', 'HSIU26', 'HSIZ26', 'HSIZ27', 'HSIZ28', 'HSIZ29', 'HSIZ30']
#   Data on disk  : 20 days  (2026-02-02 → 2026-02-27)
#   URL           : https://www.hkex.com.hk/Products/Listed-Derivatives/Equity-Index/Hang-Seng-Index-(HSI)/Hang-Seng-Index-Futures?sc_lang=en#&product=HSI
# ────────────────────────────────────────────────────────────

# %%
# Get info inside a dict
HSI_info = dr.get_info("HSI")

# %% [markdown]
# **Available contracts**

# %%
dr.get_contracts("FDAX", "2025-05-02")
# Out:
# ['FDAXM25',
#  'FDAXU25',
#  'FDAXZ25',
#  'FDAX_CAL_M25U25',
#  'FDAX_CAL_M25Z25',
#  'FDAX_CAL_U25Z25']

# %%
dr.get_contract_stats("FDAXM25", "2025-05-02")
# Out:
# {'contract': 'FDAXM25',
#  'date': '2025-05-02',
#  'schema': 'mbo',
#  'session': 'full',
#  'n_rows': 3088151,
#  'n_add': 1510405,
#  'n_cancel': 1511634,
#  'n_modify': 1704,
#  'n_trade': 32218,
#  'n_fill': 32187,
#  'n_clear': 3,
#  'cancel_rate': 1.0008,
#  'fill_rate': 0.0213,
#  'order_to_trade_ratio': 46.88,
#  'price_min': 22791000000000,
#  'price_max': 23293000000000,
#  'price_min_pts': 22791.0,
#  'price_max_pts': 23293.0,
#  'price_range_ticks': 1004,
#  'tick_size_pts': 0.5}
